# %% [markdown]
# <a href="https://colab.research.google.com/github/Soumi7/TMmodel11/blob/master/posenet_pytorch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/rwightman/posenet-pytorch.git
# Out:
# Cloning into 'posenet-pytorch'...
# remote: Enumerating objects: 115, done.
# remote: Total 115 (delta 0), reused 0 (delta 0), pack-reused 115
# Receiving objects: 100% (115/115), 35.03 KiB | 1.46 MiB/s, done.
# Resolving deltas: 100% (61/61), done.

# %%
pip install torchvision

# %%
pip install requests opencv-python==3.4.5.20
# Out:
# ...
#      |████████████████████████████████| 25.4MB 116kB/s
# ...
# ERROR: albumentations 0.1.12 has requirement imgaug<0.2.7,>=0.2.5, but you'll have imgaug 0.2.9 which is incompatible.
# ...
#   Found existing installation: opencv-python 4.1.2.30
#     Uninstalling opencv-python-4.1.2.30:
#       Successfully uninstalled opencv-python-4.1.2.30
# ...

# %%
# %cd posenet-pytorch
# !ls
# Out:
# /content/posenet-pytorch
# benchmark.py	    image_demo.py  NOTICE.txt  README.md
# get_test_images.py  LICENSE.txt    posenet     webcam_demo.py

# %%
# !python get_test_images.py

# %%
# !python image_demo.py --model 101 --image_dir /content/posenet-pytorch/images --output_dir /content/posenet-pytorch/output
# Out:
# Results for image: /content/posenet-pytorch/images/tennis_standing.jpg
# Pose #0, score = 0.346157
# Keypoint nose, score = 0.998153, coord = [ 94.80768228 210.72931933]
# Keypoint leftEye, score = 0.997842, coord = [ 79.43778175 238.40529108]
# Keypoint rightEye, score = 0.997214, coord = [ 78.32532763 208.01651552]
# Keypoint leftEar, score = 0.148690, coord = [110.49205303 291.4316082 ]
# Keypoint rightEar, score = 0.009728, coord = [ 96.91732019 195.37603569]
# Keypoint leftShoulder, score = 0.336740, coord = [230.01045513 337.18846893]
# Keypoint rightShoulder, score = 0.186018, coord = [228.86761761 169.07699203]
# Keypoint leftElbow, score = 0.060269, coord = [381.40782166 433.86097717]
# Keypoint rightElbow, score = 0.113687, coord = [391.14232159 127.9980135 ]
# Keypoint leftWrist, score = 0.885822, coord = [420.745965   347.95629406]
# Keypoint rightWrist, score = 0.682206, coord = [452.17184734 122.57627106]
# ...
